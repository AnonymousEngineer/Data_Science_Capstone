# %% [markdown]
# # Data Science Capstone Project - The Battle of Neighborhoods (Part 2)

# %%
import pandas as pd
import numpy as np
import requests
import geocoder
import folium # map rendering library
from geopy.geocoders import Nominatim
import matplotlib.pyplot as plt
import matplotlib.cm as cmap
import matplotlib.colors as colors
# %matplotlib inline
import os

# %% [markdown]
# ## define a function to get tlatitude and longitude of a given location using geopy

# %%
# function that returns latitude and longitude of a given location using geopy
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %% [markdown]
# ## define a function to interact with FourSquare API and get top 100 venues within a radius of 1000 metres for a given latitude and longitude

# %%
# function that returns top 100 venues within 1000 metres of given latitude and longitude
def get_venues(lat,lng): 
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = 'Y2T54KTNTK3DPWFSIC5QGX3HBZR5FI5CP0IWLHQTLHHLWV4V' # Foursquare ID
    CLIENT_SECRET = '5EAX0XGETHH401KQCZSU2IQDETD4X0W5QWLO0KGNMF11AFGW'# Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    #print(venue)
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df_venue_details = pd.DataFrame(venue_details,columns=column_names)
    return df_venue_details

# %% [markdown]
# ##  define a function to get venue details like like count , rating , tip counts for a given venue id

# %%
# function that returns venue details(counts , ratings , tip counts
def get_venue_details(venue_id):
    CLIENT_ID = 'Y2T54KTNTK3DPWFSIC5QGX3HBZR5FI5CP0IWLHQTLHHLWV4V' # Foursquare ID
    CLIENT_SECRET = '5EAX0XGETHH401KQCZSU2IQDETD4X0W5QWLO0KGNMF11AFGW' # Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get the data
    results = requests.get(url).json()["response"]['groups'][0]['items']
    #venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ## define a funtion to get the new york city data such as Boroughs, Neighborhoods along with their latitude and longitude

# %%
# define a funtion to return the new york city data (Boroughs, Neighborhoods, atitude and longitude)
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define  dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # create dataframe
    df_nyc_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        df_nyc_data = df_nyc_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return df_nyc_data

# %% [markdown]
# ## call function to get new york data

# %%
df_nyc_data = get_new_york_data()
df_nyc_data.shape
df_nyc_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# ## EDA of neighborhoods in New York City

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of Neighborhood for each Borough in New York City')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Neighborhood', fontsize=15)
df_nyc_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
plt.legend()
plt.show()

# %% [markdown]
# # check what the output lookslike for a specific coordinate
# tempdf = get_venues(40.894705, -73.847201)
# tempdf.head(5)
# tempdf[tempdf['Category'].str.contains('Pizza')]
# tempdf[tempdf['Category'].str.contains('Italian')]

# %% [markdown]
# ## we want to search for the finest pizza places in NYC
# ### We can do that by searching for either pizza places or Intalian restaurants (assuming they all serve pizza)
# #### search for a string that contains either pizza or Italian in the category column as above

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
df_pizza_nyc=pd.DataFrame(columns=column_names)
count=1
for row in df_nyc_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    pizza_resturants=venues[venues['Category'].str.contains('Pizza')]   
    #if(count % 10 == 0):
    print('(',count,'/',len(df_nyc_data),')','Pizza Resturants in '+Neighborhood+', '+Borough+':'+str(len(pizza_resturants)))
    for resturant_detail in pizza_resturants.values.tolist():
        id, name , category=resturant_detail
        df_pizza_nyc = df_pizza_nyc.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-fffda6f14b5d> in <module>
#       5 for row in df_nyc_data.values.tolist():
#       6     Borough, Neighborhood, Latitude, Longitude=row
# ----> 7     venues = get_venues(Latitude,Longitude)
#       8     pizza_resturants=venues[venues['Category'].str.contains('Pizza')]
#       9     #if(count % 10 == 0):
#
# <ipython-input-118-2a2f611dda7c> in get_venues(lat, lng)
#      20     # get the data
#      21     results = requests.get(url).json()
# ---> 22     venue_data=results["response"]['groups'][0]['items']
#      23     print(venue_data)
#      24     venue_details=[]
#
# KeyError: 'groups'

# %%
print(count)
# Out:
# 1

# %%
#results
results["response"]['groups'][0]['items']
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c537892fd2ea593cb077a28',
#    'name': 'Lollipops Gelato',
#    'location': {'address': '4120 Baychester Ave',
#     'crossStreet': 'Edenwald & Bussing Ave',
#     'lat': 40.894123150205274,
#     'lng': -73.84589162362325,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.894123150205274,
#       'lng': -73.84589162362325},
#      {'label': 'entrance', 'lat': 40.89362, 'lng': -73.843737}],
#     'distance': 127,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4120 Baychester Ave (Edenwald & Bussing Ave)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d0941735',
#      'name': 'Dessert Shop',
#      'pluralName': 'Dessert Shops',
#      'shortName': 'Desserts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c537892fd2ea593cb077a28-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d375ce799fe8eec99fd2355',
#    'name': 'Ripe Kitchen & Bar',
#    'location': {'address': '151 W Sandford Blvd',
#     'crossStreet': 'South 11th Avenue',
#     'lat': 40.898151685683544,
#     'lng': -73.83887499584462,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.898151685683544,
#       'lng': -73.83887499584462},
#      {'label': 'entrance', 'lat': 40.898292, 'lng': -73.838781}],
#     'distance': 798,
#     'postalCode': '10550',
#     'cc': 'US',
#     'neighborhood': 'South Side',
#     'city': 'Mount Vernon',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['151 W Sandford Blvd (South 11th Avenue)',
#      'Mount Vernon, NY 10550',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d144941735',
#      'name': 'Caribbean Restaurant',
#      'pluralName': 'Caribbean Restaurants',
#      'shortName': 'Caribbean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d375ce799fe8eec99fd2355-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c9e50e38afca09379b2ff15',
#    'name': "Ali's Roti Shop",
#    'location': {'address': '4216 White Plains Rd',
#     'crossStreet': 'Between 233rd and 234th street',
#     'lat': 40.89403569556059,
#     'lng': -73.8569349369388,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89403569556059,
#       'lng': -73.8569349369388},
#      {'label': 'entrance', 'lat': 40.893993, 'lng': -73.856854}],
#     'distance': 822,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4216 White Plains Rd (Between 233rd and 234th street)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d144941735',
#      'name': 'Caribbean Restaurant',
#      'pluralName': 'Caribbean Restaurants',
#      'shortName': 'Caribbean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c9e50e38afca09379b2ff15-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c10f6aece57c92804a682d2',
#    'name': "Jackie's West Indian Bakery",
#    'location': {'address': '1203 E 233rd St',
#     'crossStreet': 'Baychester Aveue',
#     'lat': 40.88928305984094,
#     'lng': -73.84330953453158,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88928305984094,
#       'lng': -73.84330953453158},
#      {'label': 'entrance', 'lat': 40.889364, 'lng': -73.843455}],
#     'distance': 686,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1203 E 233rd St (Baychester Aveue)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d144941735',
#      'name': 'Caribbean Restaurant',
#      'pluralName': 'Caribbean Restaurants',
#      'shortName': 'Caribbean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2159124',
#     'url': 'https://www.seamless.com/menu/jackies-west-indian-bakery-1203-east-233rd-street-bronx/2159124?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2159124',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c10f6aece57c92804a682d2-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c783cef3badb1f7e4244b54',
#    'name': 'Carvel Ice Cream',
#    'location': {'address': '1006 E 233rd St',
#     'lat': 40.890486685759605,
#     'lng': -73.84856772568665,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.890486685759605,
#       'lng': -73.84856772568665},
#      {'label': 'entrance', 'lat': 40.890438, 'lng': -73.848559}],
#     'distance': 483,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1006 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c9941735',
#      'name': 'Ice Cream Shop',
#      'pluralName': 'Ice Cream Shops',
#      'shortName': 'Ice Cream',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c783cef3badb1f7e4244b54-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d6af9426107f04dedeb297a',
#    'name': 'Rite Aid',
#    'location': {'address': '4232 Baychester Ave',
#     'lat': 40.896649,
#     'lng': -73.8448461,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.896649,
#       'lng': -73.8448461},
#      {'label': 'entrance', 'lat': 40.896504, 'lng': -73.844844}],
#     'distance': 293,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4232 Baychester Ave',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'shortName': 'Pharmacy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d6af9426107f04dedeb297a-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c1bed4eb306c928140763b7',
#    'name': "Jimbo's",
#    'location': {'address': '4137 White Plains Rd',
#     'crossStreet': '231st Street',
#     'lat': 40.89174013088267,
#     'lng': -73.85822584571335,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89174013088267,
#       'lng': -73.85822584571335}],
#     'distance': 984,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4137 White Plains Rd (231st Street)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16c941735',
#      'name': 'Burger Joint',
#      'pluralName': 'Burger Joints',
#      'shortName': 'Burgers',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1703808',
#     'url': 'https://www.seamless.com/menu/jimbos-hamburger-palace-4137-white-plains-rd-bronx/1703808?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1703808',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c1bed4eb306c928140763b7-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c25c212f1272d7f836385c5',
#    'name': "Dunkin'",
#    'location': {'address': '980 E 233rd St',
#     'crossStreet': 'Paulding Ave',
#     'lat': 40.8904587811365,
#     'lng': -73.84908886747644,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8904587811365,
#       'lng': -73.84908886747644},
#      {'label': 'entrance', 'lat': 40.890549, 'lng': -73.849231}],
#     'distance': 498,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['980 E 233rd St (Paulding Ave)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d148941735',
#      'name': 'Donut Shop',
#      'pluralName': 'Donut Shops',
#      'shortName': 'Donuts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1984066',
#     'url': 'https://www.seamless.com/menu/dunkin-980-e-233rd-st-bronx/1984066?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1984066',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c25c212f1272d7f836385c5-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5d5f5044d0ae1c0008f043c3',
#    'name': 'Walgreens',
#    'location': {'address': '4232 Baychester Ave',
#     'crossStreet': 'Pitman',
#     'lat': 40.896528,
#     'lng': -73.8447,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.896528,
#       'lng': -73.8447}],
#     'distance': 292,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4232 Baychester Ave (Pitman)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'shortName': 'Pharmacy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5d5f5044d0ae1c0008f043c3-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4beda0fc6e8c20a14aa97061',
#    'name': 'Rite Aid',
#    'location': {'address': '1179 E 233rd St',
#     'lat': 40.8890623,
#     'lng': -73.8429927,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8890623,
#       'lng': -73.8429927}],
#     'distance': 721,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1179 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'shortName': 'Pharmacy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4beda0fc6e8c20a14aa97061-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d33665fb6093704b80001e0',
#    'name': 'Subway',
#    'location': {'address': '980 E 233rd St',
#     'lat': 40.89046821651127,
#     'lng': -73.8491520209833,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89046821651127,
#       'lng': -73.8491520209833}],
#     'distance': 499,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['980 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c5941735',
#      'name': 'Sandwich Place',
#      'pluralName': 'Sandwich Places',
#      'shortName': 'Sandwiches',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '293568',
#     'url': 'https://www.seamless.com/menu/subway-980-e-233rd-st-bronx/293568?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=293568',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d33665fb6093704b80001e0-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c81a91c51ada1cd87741510',
#    'name': 'Shell',
#    'location': {'address': '836 E 233rd St',
#     'lat': 40.894187118166535,
#     'lng': -73.84586195733382,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.894187118166535,
#       'lng': -73.84586195733382}],
#     'distance': 126,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['836 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113951735',
#      'name': 'Gas Station',
#      'pluralName': 'Gas Stations',
#      'shortName': 'Gas Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c81a91c51ada1cd87741510-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4be5f0eacf200f47d1fa133c',
#    'name': "McDonald's",
#    'location': {'address': '724 E 241st St',
#     'lat': 40.90264544569362,
#     'lng': -73.84948544204235,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.90264544569362,
#       'lng': -73.84948544204235},
#      {'label': 'entrance', 'lat': 40.902685, 'lng': -73.849513}],
#     'distance': 904,
#     'postalCode': '10470',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['724 E 241st St',
#      'Bronx, NY 10470',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16e941735',
#      'name': 'Fast Food Restaurant',
#      'pluralName': 'Fast Food Restaurants',
#      'shortName': 'Fast Food',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1338352',
#     'url': 'https://www.seamless.com/menu/mcdonalds-724-e-241st-st-bronx/1338352?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1338352',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4be5f0eacf200f47d1fa133c-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c1aa37fb9f876b098fc7846',
#    'name': 'T-Mobile',
#    'location': {'address': '4198 White Plains Rd',
#     'crossStreet': 'E 233rd St',
#     'lat': 40.8932163,
#     'lng': -73.8572509,
#     'labeledLatLngs': [{'label': 'entrance',
#       'lat': 40.893172,
#       'lng': -73.857308},
#      {'label': 'display', 'lat': 40.8932163, 'lng': -73.8572509}],
#     'distance': 861,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4198 White Plains Rd (E 233rd St)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#      'name': 'Mobile Phone Shop',
#      'pluralName': 'Mobile Phone Shops',
#      'shortName': 'Mobile Phones',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c1aa37fb9f876b098fc7846-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e3b2b9a1495bf24a5bcf1cb',
#    'name': 'Walgreens',
#    'location': {'address': '4401 White Plains Rd',
#     'lat': 40.89875681347848,
#     'lng': -73.85444551706314,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89875681347848,
#       'lng': -73.85444551706314},
#      {'label': 'entrance', 'lat': 40.898674, 'lng': -73.854339}],
#     'distance': 758,
#     'postalCode': '10470',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4401 White Plains Rd',
#      'Bronx, NY 10470',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'shortName': 'Pharmacy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e3b2b9a1495bf24a5bcf1cb-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5c3665e99d7468002c5da87d',
#    'name': 'Popeyes Louisiana Kitchen',
#    'location': {'address': '4397 White Plains Rd.',
#     'lat': 40.89836291415397,
#     'lng': -73.85474315537252,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89836291415397,
#       'lng': -73.85474315537252}],
#     'distance': 754,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4397 White Plains Rd.',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#      'name': 'Fried Chicken Joint',
#      'pluralName': 'Fried Chicken Joints',
#      'shortName': 'Fried Chicken',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1188379',
#     'url': 'https://www.seamless.com/menu/popeyes-4397-white-plains-rd-bronx/1188379?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1188379',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5c3665e99d7468002c5da87d-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b6dbb78f964a520968a2ce3',
#    'name': "Domino's Pizza",
#    'location': {'address': '686C Nereid Ave',
#     'lat': 40.89844256649264,
#     'lng': -73.85485053062439,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89844256649264,
#       'lng': -73.85485053062439}],
#     'distance': 766,
#     'postalCode': '10470',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['686C Nereid Ave',
#      'Bronx, NY 10470',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b6dbb78f964a520968a2ce3-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cd3edd25366548131a129ed',
#    'name': 'E&L Bakery',
#    'location': {'address': '4202 White Plains Rd',
#     'crossStreet': '233rd Street',
#     'lat': 40.893564000000005,
#     'lng': -73.85699699999999,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.893564000000005,
#       'lng': -73.85699699999999},
#      {'label': 'entrance', 'lat': 40.893591, 'lng': -73.85708}],
#     'distance': 834,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4202 White Plains Rd (233rd Street)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1163727',
#     'url': 'https://www.seamless.com/menu/e--l-bakery-cafe-4202-white-plains-rd-bronx/1163727?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1163727',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '77053551'}},
#   'referralId': 'e-0-4cd3edd25366548131a129ed-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4dc718002271f2705156356b',
#    'name': 'Fine Fare',
#    'location': {'address': '1199 E 233rd St',
#     'lat': 40.88924476474482,
#     'lng': -73.84357937403945,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88924476474482,
#       'lng': -73.84357937403945},
#      {'label': 'entrance', 'lat': 40.88933, 'lng': -73.843607}],
#     'distance': 679,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1199 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#      'name': 'Supermarket',
#      'pluralName': 'Supermarkets',
#      'shortName': 'Supermarket',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4dc718002271f2705156356b-18'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bdc00132a3a0f47cd42b1b6',
#    'name': "Dunkin'",
#    'location': {'address': '4399A White Plains Rd',
#     'crossStreet': 'Nereid Ave',
#     'lat': 40.89838958635662,
#     'lng': -73.85464265921001,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89838958635662,
#       'lng': -73.85464265921001}],
#     'distance': 748,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4399A White Plains Rd (Nereid Ave)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d148941735',
#      'name': 'Donut Shop',
#      'pluralName': 'Donut Shops',
#      'shortName': 'Donuts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1988145',
#     'url': 'https://www.seamless.com/menu/dunkin-4399a-white-plains-rd-bronx/1988145?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1988145',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bdc00132a3a0f47cd42b1b6-19'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '59ea0da7872f7d28f0f4f428',
#    'name': 'Shell',
#    'location': {'address': '836 E 233rd St',
#     'lat': 40.891771000000006,
#     'lng': -73.853213,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.891771000000006,
#       'lng': -73.853213},
#      {'label': 'entrance', 'lat': 40.891805, 'lng': -73.853184}],
#     'distance': 602,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['836 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113951735',
#      'name': 'Gas Station',
#      'pluralName': 'Gas Stations',
#      'shortName': 'Gas Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '590427351'}},
#   'referralId': 'e-0-59ea0da7872f7d28f0f4f428-20'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4fb533867beb65c72e11e47f',
#    'name': 'Chase Bank',
#    'location': {'address': '725 E 233rd St',
#     'lat': 40.893297,
#     'lng': -73.856222,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.893297,
#       'lng': -73.856222},
#      {'label': 'entrance', 'lat': 40.893191, 'lng': -73.856157}],
#     'distance': 775,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['725 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10a951735',
#      'name': 'Bank',
#      'pluralName': 'Banks',
#      'shortName': 'Bank',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4fb533867beb65c72e11e47f-21'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c8e4302ad70a143700f880f',
#    'name': 'Popeyes Louisiana Kitchen',
#    'location': {'address': '1201 E 233rd St',
#     'crossStreet': 'Baychester Ave.',
#     'lat': 40.889502652424504,
#     'lng': -73.84338927759532,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.889502652424504,
#       'lng': -73.84338927759532}],
#     'distance': 662,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1201 E 233rd St (Baychester Ave.)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#      'name': 'Fried Chicken Joint',
#      'pluralName': 'Fried Chicken Joints',
#      'shortName': 'Fried Chicken',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1278694',
#     'url': 'https://www.seamless.com/menu/popeyes-1201-e-233rd-st-bronx/1278694?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1278694',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c8e4302ad70a143700f880f-22'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e17245245ddc623eb0f8fc6',
#    'name': 'Foodtown',
#    'location': {'lat': 40.896418935039556,
#     'lng': -73.85564224112738,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.896418935039556,
#       'lng': -73.85564224112738}],
#     'distance': 735,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Bronx, NY 10466', 'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#      'name': 'Supermarket',
#      'pluralName': 'Supermarkets',
#      'shortName': 'Supermarket',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e17245245ddc623eb0f8fc6-23'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4dda9be4c65bee535afd6d2e',
#    'name': 'Capital One Bank',
#    'location': {'address': '4201 White Plains Rd',
#     'lat': 40.89374018544049,
#     'lng': -73.85745366780156,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89374018544049,
#       'lng': -73.85745366780156},
#      {'label': 'entrance', 'lat': 40.893716, 'lng': -73.857397}],
#     'distance': 869,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4201 White Plains Rd',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10a951735',
#      'name': 'Bank',
#      'pluralName': 'Banks',
#      'shortName': 'Bank',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4dda9be4c65bee535afd6d2e-24'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bab4c66f964a520be9e3ae3',
#    'name': "Dunkin'",
#    'location': {'address': '712 E 233rd St',
#     'crossStreet': 'White Plains Rd',
#     'lat': 40.89306385538046,
#     'lng': -73.85697719386576,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89306385538046,
#       'lng': -73.85697719386576},
#      {'label': 'entrance', 'lat': 40.893128, 'lng': -73.857009}],
#     'distance': 842,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['712 E 233rd St (White Plains Rd)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d148941735',
#      'name': 'Donut Shop',
#      'pluralName': 'Donut Shops',
#      'shortName': 'Donuts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1984154',
#     'url': 'https://www.seamless.com/menu/dunkin-712-e-233rd-st-bronx/1984154?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1984154',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bab4c66f964a520be9e3ae3-25'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cd49e342944b1f7623458ec',
#    'name': 'Shell',
#    'location': {'address': '1217 E 233rd St',
#     'crossStreet': 'Bussing Ave',
#     'lat': 40.888851165771484,
#     'lng': -73.84249114990234,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.888851165771484,
#       'lng': -73.84249114990234}],
#     'distance': 762,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1217 E 233rd St (Bussing Ave)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113951735',
#      'name': 'Gas Station',
#      'pluralName': 'Gas Stations',
#      'shortName': 'Gas Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4cd49e342944b1f7623458ec-26'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f32458019836c91c7c734ff',
#    'name': 'Central Deli',
#    'location': {'address': '2020 Pitman Ave',
#     'lat': 40.896728,
#     'lng': -73.844387,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.896728,
#       'lng': -73.844387},
#      {'label': 'entrance', 'lat': 40.896774, 'lng': -73.84432}],
#     'distance': 326,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['2020 Pitman Ave',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d146941735',
#      'name': 'Deli / Bodega',
#      'pluralName': 'Delis / Bodegas',
#      'shortName': 'Deli / Bodega',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f32458019836c91c7c734ff-27'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e4e0e38bd4101d0d7a12e00',
#    'name': "McDonald's",
#    'location': {'address': '1201 E 233rd St',
#     'lat': 40.889434814453125,
#     'lng': -73.84336853027344,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.889434814453125,
#       'lng': -73.84336853027344}],
#     'distance': 669,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1201 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16e941735',
#      'name': 'Fast Food Restaurant',
#      'pluralName': 'Fast Food Restaurants',
#      'shortName': 'Fast Food',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e4e0e38bd4101d0d7a12e00-28'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55aa92ac498e24734cd2e378',
#    'name': 'Louis Pizza',
#    'location': {'address': '1840 Nereid Ave',
#     'crossStreet': 'Ely Ave',
#     'lat': 40.898399,
#     'lng': -73.84881,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.898399,
#       'lng': -73.84881}],
#     'distance': 432,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1840 Nereid Ave (Ely Ave)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55aa92ac498e24734cd2e378-29'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b8b057ff964a520c38e32e3',
#    'name': 'Rite Aid',
#    'location': {'address': '4389 White Plains Rd',
#     'crossStreet': 'Nereid Ave',
#     'lat': 40.89851188277123,
#     'lng': -73.8553595778686,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89851188277123,
#       'lng': -73.8553595778686},
#      {'label': 'entrance', 'lat': 40.898085, 'lng': -73.854838}],
#     'distance': 806,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4389 White Plains Rd (Nereid Ave)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'shortName': 'Pharmacy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b8b057ff964a520c38e32e3-30'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f6e2346e4b03b575cdceb3e',
#    'name': 'Dee-Lectable Pleasure Cakes',
#    'location': {'lat': 40.890736042333955,
#     'lng': -73.85183339667164,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.890736042333955,
#       'lng': -73.85183339667164}],
#     'distance': 589,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Bronx, NY 10466', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f6e2346e4b03b575cdceb3e-31'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4eb046abb8f7116f21081aeb',
#    'name': 'Baychester Avenue Food Truck',
#    'location': {'address': 'Baychester Avenue',
#     'crossStreet': '233rd Street',
#     'lat': 40.890479268747484,
#     'lng': -73.84272476029565,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.890479268747484,
#       'lng': -73.84272476029565}],
#     'distance': 602,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Baychester Avenue (233rd Street)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1cb941735',
#      'name': 'Food Truck',
#      'pluralName': 'Food Trucks',
#      'shortName': 'Food Truck',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4eb046abb8f7116f21081aeb-32'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4edbac4e775bcc53fc0ed5f8',
#    'name': 'Hong Kong China King',
#    'location': {'address': '1213 E 233rd St',
#     'crossStreet': 'Baychester Avenue',
#     'lat': 40.88956832885742,
#     'lng': -73.84291076660156,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88956832885742,
#       'lng': -73.84291076660156}],
#     'distance': 676,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1213 E 233rd St (Baychester Avenue)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'shortName': 'Chinese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4edbac4e775bcc53fc0ed5f8-33'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c239a63136d20a14775e061',
#    'name': 'Rite Aid',
#    'location': {'address': '4159 White Plains Rd',
#     'crossStreet': 'E 231st St',
#     'lat': 40.8922837,
#     'lng': -73.8583027,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8922837,
#       'lng': -73.8583027}],
#     'distance': 972,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4159 White Plains Rd (E 231st St)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'shortName': 'Pharmacy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2170765',
#     'url': 'https://www.seamless.com/menu/rite-way-deli-4168-white-plains-road-bronx/2170765?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2170765',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c239a63136d20a14775e061-34'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bbe730782a2ef3be56d2bd2',
#    'name': 'Associated Supermarket',
#    'location': {'address': '4141 Laconia Ave',
#     'lat': 40.88796975874366,
#     'lng': -73.84692879859317,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88796975874366,
#       'lng': -73.84692879859317},
#      {'label': 'entrance', 'lat': 40.888303, 'lng': -73.846896}],
#     'distance': 750,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4141 Laconia Ave',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#      'name': 'Supermarket',
#      'pluralName': 'Supermarkets',
#      'shortName': 'Supermarket',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bbe730782a2ef3be56d2bd2-35'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50bec2b2e4b0a04b0e6dc92f',
#    'name': 'Bee Line 42 MTA NYCT BX39 MTABus BXM11 (White Plains Road/238th St)',
#    'location': {'lat': 40.89821356300333,
#     'lng': -73.85453259642759,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89821356300333,
#       'lng': -73.85453259642759}],
#     'distance': 730,
#     'postalCode': '10470',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Bronx, NY 10470', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fe931735',
#      'name': 'Bus Station',
#      'pluralName': 'Bus Stations',
#      'shortName': 'Bus Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50bec2b2e4b0a04b0e6dc92f-36'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b897beff964a520c43a32e3',
#    'name': 'Mandarin House',
#    'location': {'address': '4129 Laconia Ave',
#     'lat': 40.888139,
#     'lng': -73.84711899999999,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.888139,
#       'lng': -73.84711899999999},
#      {'label': 'entrance', 'lat': 40.887934, 'lng': -73.8471}],
#     'distance': 730,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4129 Laconia Ave',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'shortName': 'Chinese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b897beff964a520c43a32e3-37'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bec3ac661aca5935cfe8500',
#    'name': 'El Mangu Tipico Restaurant',
#    'location': {'address': '748 E 233rd St',
#     'lat': 40.89289063331684,
#     'lng': -73.85582475342396,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89289063331684,
#       'lng': -73.85582475342396}],
#     'distance': 753,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['748 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d150941735',
#      'name': 'Spanish Restaurant',
#      'pluralName': 'Spanish Restaurants',
#      'shortName': 'Spanish',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bec3ac661aca5935cfe8500-38'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5ba5feb53fcee8002cc33168',
#    'name': 'Metro by T-Mobile',
#    'location': {'address': '4365 White Plains Rd',
#     'lat': 40.89760984082104,
#     'lng': -73.85535771685647,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89760984082104,
#       'lng': -73.85535771685647},
#      {'label': 'entrance', 'lat': 40.897547, 'lng': -73.85527}],
#     'distance': 758,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4365 White Plains Rd',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#      'name': 'Mobile Phone Shop',
#      'pluralName': 'Mobile Phone Shops',
#      'shortName': 'Mobile Phones',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5ba5feb53fcee8002cc33168-39'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bc256eb920eb713cd1b1c2c',
#    'name': "McDonald's",
#    'location': {'address': '4174 White Plains Rd',
#     'lat': 40.892779,
#     'lng': -73.857473,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.892779,
#       'lng': -73.857473},
#      {'label': 'entrance', 'lat': 40.892804, 'lng': -73.857507}],
#     'distance': 890,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4174 White Plains Rd',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16e941735',
#      'name': 'Fast Food Restaurant',
#      'pluralName': 'Fast Food Restaurants',
#      'shortName': 'Fast Food',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1339326',
#     'url': 'https://www.seamless.com/menu/mcdonalds-4174-white-plains-rd-bronx/1339326?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1339326',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bc256eb920eb713cd1b1c2c-40'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e16230ca8090df1ec993bfb',
#    'name': 'PAYOMATIC',
#    'location': {'address': '686A Nereid Ave',
#     'lat': 40.898492237889734,
#     'lng': -73.85500743985176,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.898492237889734,
#       'lng': -73.85500743985176}],
#     'distance': 780,
#     'postalCode': '10470',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['686A Nereid Ave',
#      'Bronx, NY 10470',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b2d',
#      'name': 'Check Cashing Service',
#      'pluralName': 'Check Cashing Services',
#      'shortName': 'Check Cashing Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e16230ca8090df1ec993bfb-41'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ba10dc5f964a520019337e3',
#    'name': "Original Joe's Pizza",
#    'location': {'address': '716 E 233rd St',
#     'lat': 40.893337423606994,
#     'lng': -73.85710509714613,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.893337423606994,
#       'lng': -73.85710509714613},
#      {'label': 'entrance', 'lat': 40.893446, 'lng': -73.857063}],
#     'distance': 847,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['716 E 233rd St',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ba10dc5f964a520019337e3-42'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e4decf6bd4101d0d79e5acf',
#    'name': 'Kennedy Fried Chicken & Pizza',
#    'location': {'address': '4180 White Plains Rd',
#     'lat': 40.892988,
#     'lng': -73.85725699999999,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.892988,
#       'lng': -73.85725699999999},
#      {'label': 'entrance', 'lat': 40.892886, 'lng': -73.857463}],
#     'distance': 867,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4180 White Plains Rd',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#      'name': 'Fried Chicken Joint',
#      'pluralName': 'Fried Chicken Joints',
#      'shortName': 'Fried Chicken',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1206547',
#     'url': 'https://www.seamless.com/menu/super-kennedy-fried-chicken-4180-white-plains-rd-bronx/1206547?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1206547',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e4decf6bd4101d0d79e5acf-43'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4dc5add8c65b89d3ca7584bb',
#    'name': "Original Tony's Pizza",
#    'location': {'address': '4189 White Plains Rd',
#     'crossStreet': '233rd Street',
#     'lat': 40.893301,
#     'lng': -73.857765,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.893301,
#       'lng': -73.857765}],
#     'distance': 902,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4189 White Plains Rd (233rd Street)',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4dc5add8c65b89d3ca7584bb-44'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e17072118388d0d26849fcc',
#    'name': 'Seton Falls Park',
#    'location': {'crossStreet': 'Baychester Avenue & Crawford Avenue',
#     'lat': 40.8884138255166,
#     'lng': -73.84018621289728,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8884138255166,
#       'lng': -73.84018621289728}],
#     'distance': 915,
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Baychester Avenue & Crawford Avenue',
#      'Bronx, NY',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d163941735',
#      'name': 'Park',
#      'pluralName': 'Parks',
#      'shortName': 'Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e17072118388d0d26849fcc-45'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '515a1329e4b0e5686040c8bd',
#    'name': 'Deals',
#    'location': {'address': '4225 White Plains Rd',
#     'lat': 40.89447021484375,
#     'lng': -73.85712432861328,
#     'labeledLatLngs': [{'label': 'entrance',
#       'lat': 40.894332,
#       'lng': -73.857057},
#      {'label': 'display',
#       'lat': 40.89447021484375,
#       'lng': -73.85712432861328}],
#     'distance': 835,
#     'postalCode': '10466',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['4225 White Plains Rd',
#      'Bronx, NY 10466',
#      'United States']},
#    'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#      'name': 'Discount Store',
#      'pluralName': 'Discount Stores',
#      'shortName': 'Discount Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-515a1329e4b0e5686040c8bd-46'}]

# %%
get_venues(40.894705,-73.847201)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-1a3dddbc722c> in <module>
# ----> 1 get_venues(40.894705,-73.847201)
#
# <ipython-input-118-2a2f611dda7c> in get_venues(lat, lng)
#      20     # get the data
#      21     results = requests.get(url).json()
# ---> 22     venue_data=results["response"]['groups'][0]['items']
#      23     print(venue_data)
#      24     venue_details=[]
#
# KeyError: 'groups'

# %%
df_pizza_nyc.head()

# %%
##  Visualize with a bar plot to see which borough has highest number of Pizza restaurants

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of Pizza Resturants for each Borough in New York City')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Pizza Resturants', fontsize=15)
df_pizza_nyc.groupby('Borough')['ID'].count().plot(kind='bar')
plt.legend()
plt.show()

# %%
##  Visualize with a bar plot to see which Neighborhood has highest number of Pizza restaurants

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of Pizza Resturants for each Neighborhood in New York City')
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('No.of Pizza Resturants', fontsize=15)
df_pizza_nyc.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
plt.legend()
plt.show()

# %% [markdown]
# ### find the restaurants in

# %%
df_pizza_nyc[df_pizza_nyc['Neighborhood']=='Bronxdale']

# %% [markdown]
# ## Analyze the rankings of the restaurants

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
df_pizza_nyc_stats = pd.DataFrame(columns=column_names)
count=1

for row in df_pizza_nyc.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    if(count % 10 == 0):
        print('(',count,'/',len(df_pizza_nyc),')','processed')
    df_pizza_nyc_stats = df_pizza_nyc_stats.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1

# %%
# inspect the stats data
df_pizza_nyc_stats.head()
df_pizza_nyc_stats.shape

#save the CSV of the stats
df_pizza_nyc_stats.to_csv('df_pizza_nyc_stats.csv', index=False)

# %%
# check data type of columns 
df_pizza_nyc_stats.info()

# convert data types
df_pizza_nyc_stats['Likes']=df_pizza_nyc_stats['Likes'].astype('float64')
df_pizza_nyc_stats['Tips']=df_pizza_nyc_stats['Tips'].astype('float64')
df_pizza_nyc_stats.info()

# %% [markdown]
# ## Let's find tht top restaurants in NYC

# %%
# Resturant with maximum Likes
df_pizza_nyc_stats.iloc[df_pizza_nyc_stats['Likes'].idxmax()]

# %%
# Resturant with maximum Rating
df_pizza_nyc_stats.iloc[df_pizza_nyc_stats['Rating'].idxmax()]

# %%
# Resturant with maximum Tips
df_pizza_nyc_stats.iloc[df_pizza_nyc_stats['Tips'].idxmax()]

# %% [markdown]
# ## Let's find the top neighborhoods (based on restaurants of course)

# %%
ny_neighborhood_stats=df_pizza_nyc_stats.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)

# %% [markdown]
# ##  Top boroughs with top average rating of Indian resturants

# %%
ny_borough_stats=indian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()

# %% [markdown]
# ## Generate a bar chart

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Average rating of Indian Resturants for each Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
ny_borough_stats.groupby('Borough').mean()['Rating'].plot(kind='bar')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-1ed296eccddd> in <module>
#       3 plt.xlabel('Borough', fontsize = 15)
#       4 plt.ylabel('Average Rating', fontsize=15)
# ----> 5 ny_borough_stats.groupby('Borough').mean()['Rating'].plot(kind='bar')
#       6 plt.legend()
#       7 plt.show()
#
# NameError: name 'ny_borough_stats' is not defined

# %% [markdown]
# ## Visualize neighborhoods with average rating greater or equal 8.0 on map

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]
ny_neighborhood_stats

# %%
# join the dataframes
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,new_york_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats

# %%
# create the map
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %% [markdown]
# ###  add a new field to dataframe for labeling purpose

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)

# %% [markdown]
#  ### Now that we have visualized the Neighborhoods.
#  ### Lets Visualize Boroughs based on average Rating

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
ny_geo = r'Borough Boundaries.geojson'

ny_map.choropleth(
    geo_data=ny_geo,
    data=ny_borough_stats,
    columns=['Borough', 'Average Rating'],
    key_on='feature.properties.boro_name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average Rating'
)

# display map
# as this is huge map data , we will save it to a file
ny_map.save('borough_rating.html')
